# %%
from ultralytics import YOLO
from functions.benchmark import benchmark

model = YOLO('yolov8n.pt')  # load a pretrained model

model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=False,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    device="cuda"
)

results_fp32 = benchmark(
    YOLO('yolov8n.engine'),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)

results_fp32
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 0.8s, saved as 'yolov8n.onnx' (12.2 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# [05/01/2025-07:12:40] [TRT] [I] [MemUsageChange] Init CUDA: CPU -2, GPU +0, now: CPU 657, GPU 252 (MiB)
# [05/01/2025-07:12:43] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +1141, GPU +192, now: CPU 1935, GPU 444 (MiB)
# [05/01/2025-07:12:43] [TRT] [I] ----------------------------------------------------------------
# [05/01/2025-07:12:43] [TRT] [I] Input filename:   yolov8n.onnx
# [05/01/2025-07:12:43] [TRT] [I] ONNX IR version:  0.0.9
# ...

# %%
from ultralytics import YOLO
from functions.benchmark import benchmark

model = YOLO('yolov8n.pt')  # load a pretrained model

model.export(
    format="engine",
    imgsz=640,
    half=True,
    int8=False,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    device="cuda"
)

results_fp16 = benchmark(
    YOLO('yolov8n.engine'),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)

results_fp16
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 0.7s, saved as 'yolov8n.onnx' (12.2 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# [05/01/2025-07:17:57] [TRT] [I] [MemUsageChange] Init CUDA: CPU -2, GPU +0, now: CPU 657, GPU 252 (MiB)
# [05/01/2025-07:17:58] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +1140, GPU +192, now: CPU 1935, GPU 444 (MiB)
# [05/01/2025-07:17:58] [TRT] [I] ----------------------------------------------------------------
# [05/01/2025-07:17:58] [TRT] [I] Input filename:   yolov8n.onnx
# [05/01/2025-07:17:58] [TRT] [I] ONNX IR version:  0.0.9
# ...

# %%
from ultralytics import YOLO
from functions.benchmark import benchmark
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="/home/omni/Programming/QRID/QRID/augmented_sets/calibration_025.yaml",
    fraction=1,
    device="cuda"
)

results_static_025 = benchmark(
    YOLO('yolov8n.engine'),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)
results_static_025

# %%
from ultralytics import YOLO
from functions.benchmark import benchmark
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

exported_model_path = model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="coco.yaml",
    fraction=0.1,
    device="cuda"
)

results = benchmark(
    YOLO(exported_model_path),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)
results
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 10.2s, saved as 'yolov8n.onnx' (12.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: collecting INT8 calibration images from 'data=coco.yaml'
# Scanning /home/omni/Programming/QRID/datasets/coco/labels/val2017... 496 images, 4 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<00:00, 2547.26it/s]
# New cache created: /home/omni/Programming/QRID/datasets/coco/labels/val2017.cache
# ...

# %%
from ultralytics import YOLO
from functions.benchmark import benchmark
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

exported_model_path = model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="coco.yaml",
    fraction=1,
    device="cuda"
)

results_static_025 = benchmark(
    YOLO(exported_model_path),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)
results_static_025
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 12.5s, saved as 'yolov8n.onnx' (12.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: collecting INT8 calibration images from 'data=/home/omni/Programming/QRID/QRID/augmented_sets/calibration_025.yaml'
# Scanning /home/omni/Programming/QRID/QRID/augmented_sets/calibration_025/labels/val2017.cache... 0 images, 999 backgrounds, 0 corrupt: 100%|██████████| 999/999 [00:00<?, ?it/s]
# ...

# %%
from ultralytics import YOLO
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

exported_model_path = model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="coco.yaml",
    fraction=1,
    device="cuda"
)

results = benchmark(
    YOLO(exported_model_path),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)
results
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 10.7s, saved as 'yolov8n.onnx' (12.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: collecting INT8 calibration images from 'data=coco.yaml'
# Scanning /home/omni/Programming/QRID/datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
# ...

# %%
from ultralytics import YOLO
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

exported_model_path = model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="/home/omni/Programming/QRID/QRID/augmented_sets/calibration_075.yaml",
    fraction=1,
    device="cuda"
)

results = benchmark(
    YOLO(exported_model_path),
    kwargs={
        "data": "coco.yaml",
        "device": "cuda",
    }
)
results
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 12.5s, saved as 'yolov8n.onnx' (12.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: collecting INT8 calibration images from 'data=/home/omni/Programming/QRID/QRID/augmented_sets/calibration_075.yaml'
# Scanning /home/omni/Programming/QRID/QRID/augmented_sets/calibration_075/labels/val2017... 0 images, 999 backgrounds, 0 corrupt: 100%|██████████| 999/999 [00:00<00:00, 7779.92it/s]
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="coco.yaml",
    imgsz=640,
    half=False,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.7/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco.yaml at imgsz=640 (155.21s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅       19.3                0.371                    2.51  398.05
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅       19.3                0.371                    2.51  398.05

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="coco.yaml",
    imgsz=640,
    half=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.8/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco.yaml at imgsz=640 (300.01s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        8.8                0.371                    1.76  569.31
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        8.8                0.371                    1.76  569.31

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_25.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.9/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_25.yaml at imgsz=640 (311.55s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.2973                    1.65  606.14
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.2973                    1.65  606.14

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_50.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.9/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_50.yaml at imgsz=640 (244.02s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2753                    1.65  606.11
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2753                    1.65  606.11
