# %%
from ultralytics import YOLO
# Export to TensorRT engine using train subset for calibration => use clean validation set with model.val() for benchmarking
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model.export(
    format="engine",
    imgsz=640,
    half=False,
    int8=True,
    dynamic=False,
    simplify=True,
    # nms=True,
    batch=1,
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/clean_coco.yaml",
    fraction=0.1,
    device="cuda"
)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 10.5s, saved as 'yolov8n.onnx' (12.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: collecting INT8 calibration images from 'data=/home/omni/Programming/QRID/QRID/my_benchmark_yaml/clean_coco.yaml'
# Scanning /home/omni/Programming/QRID/datasets/coco/labels/val2017... 496 images, 4 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<00:00, 2508.29it/s]
# New cache created: /home/omni/Programming/QRID/datasets/coco/labels/val2017.cache
# [04/30/2025-19:53:50] [TRT] [I] The logger passed into createInferBuilder differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
# [04/30/2025-19:53:52] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU -1138, GPU +164, now: CPU 5986, GPU 942 (MiB)
# [04/30/2025-19:53:52] [TRT] [I] ----------------------------------------------------------------
# [04/30/2025-19:53:52] [TRT] [I] Input filename:   yolov8n.onnx
# [04/30/2025-19:53:52] [TRT] [I] ONNX IR version:  0.0.9
# [04/30/2025-19:53:52] [TRT] [I] Opset version:    19
# [04/30/2025-19:53:52] [TRT] [I] Producer name:    pytorch
# [04/30/2025-19:53:52] [TRT] [I] Producer version: 2.6.0
# [04/30/2025-19:53:52] [TRT] [I] Domain:
# [04/30/2025-19:53:52] [TRT] [I] Model version:    0
# [04/30/2025-19:53:52] [TRT] [I] Doc string:
# [04/30/2025-19:53:52] [TRT] [I] ----------------------------------------------------------------
# TensorRT: input "images" with shape(-1, 3, -1, -1) DataType.FLOAT
# TensorRT: output "output0" with shape(-1, 84, -1) DataType.FLOAT
# TensorRT: WARNING ⚠️ 'dynamic=True' model requires max batch size, i.e. 'batch=16'
# TensorRT: building INT8 engine as yolov8n.engine
# [04/30/2025-19:53:52] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [04/30/2025-19:53:52] [TRT] [I] Reading Calibration Cache for calibrator: EntropyCalibration2
# [04/30/2025-19:53:52] [TRT] [I] Generated calibration scales using calibration cache. Make sure that calibration cache has latest scales.
# [04/30/2025-19:53:52] [TRT] [I] To regenerate calibration cache, please delete the existing one. TensorRT will generate a new calibration cache.
# [04/30/2025-19:53:52] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [04/30/2025-19:53:52] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [04/30/2025-19:56:04] [TRT] [I] Detected 1 inputs and 3 output network tensors.
# [04/30/2025-19:56:07] [TRT] [I] Total Host Persistent Memory: 341680 bytes
# [04/30/2025-19:56:07] [TRT] [I] Total Device Persistent Memory: 1799168 bytes
# [04/30/2025-19:56:07] [TRT] [I] Max Scratch Memory: 0 bytes
# [04/30/2025-19:56:07] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 139 steps to complete.
# [04/30/2025-19:56:07] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 10.3846ms to assign 10 blocks to 139 nodes requiring 12723200 bytes.
# [04/30/2025-19:56:07] [TRT] [I] Total Activation Memory: 12722176 bytes
# [04/30/2025-19:56:07] [TRT] [I] Total Weights Memory: 3495940 bytes
# [04/30/2025-19:56:07] [TRT] [I] Engine generation completed in 135.03 seconds.
# [04/30/2025-19:56:07] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 6 MiB, GPU 336 MiB
# TensorRT: export success ✅ 147.5s, saved as 'yolov8n.engine' (5.7 MB)
#
# Export complete (147.6s)
# Results saved to /home/omni/Programming/QRID/QRID
# Predict:         yolo predict task=detect model=yolov8n.engine imgsz=640 int8
# Validate:        yolo val task=detect model=yolov8n.engine imgsz=640 data=coco.yaml int8
# Visualize:       https://netron.app
# 'yolov8n.engine'

# %%
from functions.benchmark import benchmark
benchmark_results = benchmark(
    model='/home/omni/Programming/QRID/QRID/yolov8n.engine',
    kwargs={
        "data": "/home/omni/Programming/QRID/QRID/my_benchmark_yaml/clean_coco.yaml",
        "device": "cuda",
    }
)
benchmark_results
# Out:
# Model is not a YOLO object. Please provide a valid YOLO model.

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/clean_coco.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 433.9/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/clean_coco.yaml at imgsz=640 (238.94s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.3229                    1.63  614.98
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.3229                    1.63  614.98

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="coco.yaml",
    imgsz=640,
    half=False,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.7/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco.yaml at imgsz=640 (155.21s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅       19.3                0.371                    2.51  398.05
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅       19.3                0.371                    2.51  398.05

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="coco.yaml",
    imgsz=640,
    half=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.8/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco.yaml at imgsz=640 (300.01s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        8.8                0.371                    1.76  569.31
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        8.8                0.371                    1.76  569.31

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_25.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.9/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_25.yaml at imgsz=640 (311.55s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.2973                    1.65  606.14
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.8               0.2973                    1.65  606.14

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_50.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 478.9/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_50.yaml at imgsz=640 (244.02s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2753                    1.65  606.11
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2753                    1.65  606.11

# %%
from ultralytics.utils.benchmarks import benchmark
benchmark(
    model="yolov8n.pt",
    data="/home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_75.yaml",
    imgsz=640,
    half=False,
    int8=True,
    device="cuda",
    verbose=False,
    format="engine",
) # benchmark function ensures using batch size 1
# Out:
# Setup complete ✅ (12 CPUs, 31.2 GB RAM, 479.0/937.8 GB disk)
#
# Benchmarks complete for yolov8n.pt on /home/omni/Programming/QRID/QRID/my_benchmark_yaml/coco_augmented_75.yaml at imgsz=640 (237.56s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2973                    1.64  609.93
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0  TensorRT       ✅        5.7               0.2973                    1.64  609.93

# %%
engine = YOLO("/home/omni/Programming/QRID/QRID/yolov8n.engine", task="detect")

# %%
moedl
# Out:
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in in the future.
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /home/omni/Programming/QRID/datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  27%|██▋       | 1348/5000 [00:11<00:31, 115.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.val(
#       2     data="coco.yaml",
#       3     conf=0.25,
#       4     iou=0.65,
#       5     device="cuda",
#       6     half=False,
#       7     int8=True,
#       8     batch=1,
#       9     imgsz=640,
#      10     save_json=True,
#      11     save_conf=True,
#      12     save_hybrid=True,
#      13 )
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:628, in Model.val(self, validator, **kwargs)
#     625 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     627 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 628 validator(model=self.model)
#     629 self.metrics = validator.metrics
#     630 return validator.metrics
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/engine/validator.py:214, in BaseValidator.__call__(self, trainer, model)
#     212 # Inference
#     213 with dt[1]:
# --> 214     preds = model(batch["img"], augment=augment)
#     216 # Loss
#     217 with dt[2]:
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:581, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     579 # PyTorch
#     580 if self.pt or self.nn_module:
# --> 581     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     583 # TorchScript
#     584 elif self.jit:
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:120, in BaseModel.forward(self, x, *args, **kwargs)
#     118 if isinstance(x, dict):  # for cases of training and validating while training.
#     119     return self.loss(x, *args, **kwargs)
# --> 120 return self.predict(x, *args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     136 if augment:
#     137     return self._predict_augment(x)
# --> 138 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:159, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     157 if profile:
#     158     self._profile_one_layer(m, x, dt)
# --> 159 x = m(x)  # run
#     160 y.append(x if m.i in self.save else None)  # save output
#     161 if visualize:
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:300, in C2f.forward(self, x)
#     298 def forward(self, x):
#     299     """Forward pass through C2f layer."""
# --> 300     y = list(self.cv1(x).chunk(2, 1))
#     301     y.extend(m(y[-1]) for m in self.m)
#     302     return self.cv2(torch.cat(y, 1))
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:91, in Conv.forward_fuse(self, x)
#      81 def forward_fuse(self, x):
#      82     """
#      83     Apply convolution and activation without batch normalization.
#      84
#    (...)     89         (torch.Tensor): Output tensor.
#      90     """
# ---> 91     return self.act(self.conv(x))
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
