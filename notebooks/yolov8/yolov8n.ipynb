# %%
import torch
from ultralytics import YOLO

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# # Yolov8

# %% [markdown]
# ## Nano

# %% [markdown]
# ### FP32

# %%
# Load the model
model_type = "yolov8n.pt"

model = YOLO(model_type, task="detect")

# %%
from functions.export_to_onnx import export_to_onnx

# Export to ONNX
export_to_onnx(
    model_path='/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt',
    export_args={
        'device': device
    }
)
# Out:
# Loading model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt...
# Model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt loaded successfully.
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 0.9s, saved as '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx' (12.2 MB)
#
# Export complete (1.5s)
# Results saved to /home/omni/Programming/QRID/QRID/models/pt/yolov8
# Predict:         yolo predict task=detect model=/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx imgsz=640
# ...

# %%
from functions.preprocess import preprocess_model
preprocess_model('/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx', '/home/omni/Programming/QRID/QRID/models/onnx/yolov8/yolov8n/fp32/yolov8n.onnx')
# Out:
# Preprocessing model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx...
# Model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx preprocessed successfully.

# %% [markdown]
# ### FP16

# %%
from functions.export_to_onnx import export_to_onnx

# Export to ONNX
export_to_onnx(
    model_path='/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt',
    export_args={
        'half': True,
        'device': device
    }
)
# Out:
# Loading model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt...
# Model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt loaded successfully.
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 0.7s, saved as '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx' (6.1 MB)
#
# Export complete (1.2s)
# Results saved to /home/omni/Programming/QRID/QRID/models/pt/yolov8
# Predict:         yolo predict task=detect model=/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx imgsz=640 half
# ...

# %%
from functions.preprocess import preprocess_model
preprocess_model('/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx', '/home/omni/Programming/QRID/QRID/models/onnx/yolov8/yolov8n/fp16/yolov8n.onnx')
# Out:
# Preprocessing model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx...
# Model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx preprocessed successfully.

# %% [markdown]
# ### QUInt8 Dynamic Quantization

# %%
from functions.export_to_onnx import export_to_onnx

# Export to ONNX
export_to_onnx(
    model_path='/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt',
    export_args={
        'device': device
    }
)
# Out:
# Loading model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt...
# Model /home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt loaded successfully.
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 0.7s, saved as '/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx' (12.2 MB)
#
# Export complete (1.2s)
# Results saved to /home/omni/Programming/QRID/QRID/models/pt/yolov8
# Predict:         yolo predict task=detect model=/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx imgsz=640
# ...

# %%
from functions.preprocess import preprocess_model
preprocess_model('/home/omni/Programming/QRID/QRID/models/pt/yolov8/yolov8n.onnx', '/home/omni/Programming/QRID/QRID/models/onnx/yolov8/yolov8n/quint8_dynamic/yolov8n.onnx')

# %%
from functions.dynamic_quant import dynamic_quantization

model_fp32 = '/home/omni/Programming/QRID/QRID/models/onnx/yolov8/yolov8n/quint8_dynamic/yolov8n.onnx'
model_uint8 = '/home/omni/Programming/QRID/QRID/models/onnx/yolov8/yolov8n/quint8_dynamic/yolov8n_quint8'

# Apply dynamic quantization with unsigned Int8, because signed Int8 raises errors
dynamic_quantization(
    model_fp32=model_fp32,
    model_uint8=model_uint8,
)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md

# %% [markdown]
# ### Static Quantization

# %%
from timeit import default_timer as timer
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# Loading yolov8n.onnx for ONNX Runtime inference...
# Using ONNX Runtime CUDAExecutionProvider
# Setting batch=1 input of shape (1, 3, 640, 640)
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/home/omni/Programming/QRID/datasets/coco/val2017.txt'
# ...
# 2025-04-23 07:35:25.857295121 [W:onnxruntime:, transformer_memcpy.cc:83 ApplyImpl] 4 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 100%|██████████| 169M/169M [00:58<00:00, 3.03MB/s]
# Unzipping /home/omni/Programming/QRID/datasets/coco2017labels-segments.zip to /home/omni/Programming/QRID/datasets/coco...: 100%|██████████| 122232/122232 [00:14<00:00, 8434.02file/s]
# ...
