# %%
import torch
from ultralytics import YOLO
from ultralytics.utils.benchmarks import benchmark

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
model_type = "yolov8n.pt"

model = YOLO(model_type)

# # Export the model to ONNX format
model.export(
    format="onnx",
    imgsz=640,
    half=False,
    dynamic=False,
    simplify=True,
    opset=None,
    nms=False,
    batch=1,
    device=device,
) 

print(f"{model_type.split('.')[0]}.onnx")



### If dataset for benchmarking isn't provided, the `benchmark` function will download it itself
# Out:
# yolov8n.onnx

# %%
model = YOLO(f"yolov8n.onnx", task="detect")
model.task
# Out:
# 'detect'

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType, quantize_static

model_fp32 = 'yolov8n.onnx'
model_int4 = 'yolov8n_dq_int4.onnx'

# Quantize 
quantize_dynamic(model_fp32, model_int4, weight_type=QuantType.QInt4)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md

# %%
from timeit import default_timer as timer
model = YOLO(f"yolov8n_dq.onnx", task="detect")
#start_time = timer()
#model("https://ultralytics.com/images/bus.jpg")
#end_time = timer()
#print(f"Time taken for inference: {end_time - start_time:.4f} seconds")
# Customize validation settings
validation_results = model.val(data="coco.yaml", imgsz=640, batch=16, conf=0.25, iou=0.6, device="0")
# Out:
# Ultralytics 8.3.109 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2070, 7789MiB)
# Loading yolov8n_dq.onnx for ONNX Runtime inference...
# Using ONNX Runtime CUDAExecutionProvider
# Setting batch=1 input of shape (1, 3, 640, 640)
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/home/omni/Programming/QRID/datasets/coco/val2017.txt'
# Downloading https://ultralytics.com/assets/coco2017labels-segments.zip to '/home/omni/Programming/QRID/datasets/coco2017labels-segments.zip'...
# 2025-04-16 17:29:19.079290694 [W:onnxruntime:, transformer_memcpy.cc:83 ApplyImpl] 185 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 100%|██████████| 169M/169M [00:57<00:00, 3.06MB/s]
# Unzipping /home/omni/Programming/QRID/datasets/coco2017labels-segments.zip to /home/omni/Programming/QRID/datasets/coco...: 100%|██████████| 122232/122232 [00:10<00:00, 11812.57file/s]
# Downloading http://images.cocodataset.org/zips/val2017.zip to '/home/omni/Programming/QRID/datasets/coco/images/val2017.zip'...
# Downloading http://images.cocodataset.org/zips/test2017.zip to '/home/omni/Programming/QRID/datasets/coco/images/test2017.zip'...
# Downloading http://images.cocodataset.org/zips/train2017.zip to '/home/omni/Programming/QRID/datasets/coco/images/train2017.zip'...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       2 model = YOLO(f"yolov8n_dq.onnx", task="detect")
#       3 #start_time = timer()
#       4 #model("https://ultralytics.com/images/bus.jpg")
#       5 #end_time = timer()
#       6 #print(f"Time taken for inference: {end_time - start_time:.4f} seconds")
#       7 # Customize validation settings
# ----> 8 validation_results = model.val(data="coco.yaml", imgsz=640, batch=16, conf=0.25, iou=0.6, device="0")
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:628, in Model.val(self, validator, **kwargs)
#     625 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     627 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 628 validator(model=self.model)
#     629 self.metrics = validator.metrics
#     630 return validator.metrics
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/engine/validator.py:179, in BaseValidator.__call__(self, trainer, model)
#     176     LOGGER.info(f"Setting batch={self.args.batch} input of shape ({self.args.batch}, 3, {imgsz}, {imgsz})")
#     178 if str(self.args.data).split(".")[-1] in {"yaml", "yml"}:
# --> 179     self.data = check_det_dataset(self.args.data)
#     180 elif self.args.task == "classify":
#     181     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/data/utils.py:381, in check_det_dataset(dataset, autodownload)
#     379     r = os.system(s)
#     380 else:  # python script
# --> 381     exec(s, {"yaml": data})
#     382 dt = f"({round(time.time() - t, 1)}s)"
#     383 s = f"success ✅ {dt}, saved to {colorstr('bold', DATASETS_DIR)}" if r in {0, None} else f"failure {dt} ❌"
#
# File <string>:17
#
# File ~/Programming/QRID/QRID/.venv/lib/python3.12/site-packages/ultralytics/utils/downloads.py:475, in download(url, dir, unzip, delete, curl, threads, retry, exist_ok)
#     473 if threads > 1:
#     474     with ThreadPool(threads) as pool:
# --> 475         pool.map(
#     476             lambda x: safe_download(
#     477                 url=x[0],
#     478                 dir=x[1],
#     479                 unzip=unzip,
#     480                 delete=delete,
#     481                 curl=curl,
#     482                 retry=retry,
#     483                 exist_ok=exist_ok,
#     484                 progress=threads <= 1,
#     485             ),
#     486             zip(url, repeat(dir)),
#     487         )
#     488         pool.close()
#     489         pool.join()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
from timeit import default_timer as timer
model = YOLO(f"yolov8n.onnx", task="detect")
start_time = timer()
model("https://ultralytics.com/images/bus.jpg")
end_time = timer()
print(f"Time taken for inference: {end_time - start_time:.4f} seconds")
# Out:
# Loading yolov8n.onnx for ONNX Runtime inference...
# Using ONNX Runtime CUDAExecutionProvider
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# 2025-04-16 17:26:22.874675556 [W:onnxruntime:, transformer_memcpy.cc:83 ApplyImpl] 4 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# image 1/1 /home/omni/Programming/QRID/QRID/bus.jpg: 640x640 4 persons, 1 bus, 6.3ms
# Speed: 9.8ms preprocess, 6.3ms inference, 78.4ms postprocess per image at shape (1, 3, 640, 640)
# Time taken for inference: 1.0188 seconds
